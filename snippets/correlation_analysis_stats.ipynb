# %% [markdown]
# # Statistical Analysis of ETA Logs
#
# This notebook extends the normalized correlation analysis by adding descriptive statistics:
# - Mean execution time
# - Standard deviation
# - Z-scores
# - 95th percentile (p95)
# - 99th percentile (p99)
#
# These metrics help identify anomalies and performance outliers.

# %%
import pandas as pd
import numpy as np

# %%
# Load ETA logs
eta_logs = pd.read_csv('datasets/cleaned_eta_logs.csv')
eta_logs['datetime'] = pd.to_datetime(eta_logs['datetime'])
eta_logs.head()
# Out:
#                  datetime agent_type   pid  transaction_id  execution_time  \
# 0 2025-11-06 00:00:00.850  eta_agent  7964  11017737610524           4.121
# 1 2025-11-06 00:00:04.978  eta_agent  7773  11017737601406           0.099
# 2 2025-11-06 00:00:05.251  eta_agent  7690  11017737607061          10.955
# 3 2025-11-06 00:00:05.782  eta_agent  8144  11017737599261           3.988
# 4 2025-11-06 00:00:05.995  eta_agent  7771  11017737599253           4.455
#
#   source_file  line_number        date  hour  minute  is_slow  is_very_slow  \
# 0   time6.txt        82537  2025-11-06     0       0    False         False
# 1   time6.txt        44569  2025-11-06     0       0    False         False
# 2   time6.txt            1  2025-11-06     0       0    False         False
# 3   time6.txt       128222  2025-11-06     0       0    False         False
# 4   time6.txt        40181  2025-11-06     0       0    False         False
#
#    is_critical
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %% [markdown]
# ### Statistical Formulas
#
# - **Mean**:
# \[
# \mu = \frac{\sum_{i=1}^{n} x_i}{n}
# \]
#
# - **Standard Deviation**:
# \[
# \sigma = \sqrt{\frac{\sum_{i=1}^{n}(x_i - \mu)^2}{n}}
# \]
#
# - **Z-score**:
# \[
# z_i = \frac{x_i - \mu}{\sigma}
# \]
#
# - **95th Percentile (p95)**:
# \[
# p_{95} = \text{value at } 95^{th} \text{ percentile of sorted data}
# \]
#
# - **99th Percentile (p99)**:
# \[
# p_{99} = \text{value at } 99^{th} \text{ percentile of sorted data}
# \]

# %%
# Calculate descriptive statistics for execution_time
execution_times = eta_logs['execution_time']
mean_val = execution_times.mean()
std_val = execution_times.std()
p95 = np.percentile(execution_times, 95)
p99 = np.percentile(execution_times, 99)

# Compute z-scores
eta_logs['z_score'] = (execution_times - mean_val) / std_val

{
    'mean_execution_time': mean_val,
    'std_dev': std_val,
    'p95': p95,
    'p99': p99,
   # 'z-score': eta_logs
}
# Out:
# {'mean_execution_time': np.float64(3.69212020659224),
#  'std_dev': np.float64(5.999948978345758),
#  'p95': np.float64(14.229),
#  'p99': np.float64(24.958149999999993)}

# %%
# Identify outliers based on z-score > 3 or execution_time > p99
outliers = eta_logs[(eta_logs['z_score'] > 3) | (eta_logs['execution_time'] > p99)]
outliers.head()
# Out:
#                     datetime agent_type   pid  transaction_id  execution_time  \
# 1909 2025-11-06 00:22:30.014  eta_agent  7760  11017737640276          26.321
# 2082 2025-11-06 00:24:09.114  eta_agent  7760  11017737638263          25.410
# 2099 2025-11-06 00:24:22.106  eta_agent  7864  11017737627648          25.952
# 2107 2025-11-06 00:24:26.079  eta_agent  7976  11017737633002          29.538
# 5314 2025-11-06 01:06:22.670  eta_agent  7962  11017737689460          23.451
#
#      source_file  line_number        date  hour  minute  is_slow  \
# 1909   time6.txt        15674  2025-11-06     0      22     True
# 2082   time6.txt        15679  2025-11-06     0      24     True
# 2099   time6.txt        71450  2025-11-06     0      24     True
# 2107   time6.txt        84724  2025-11-06     0      24     True
# 5314   time6.txt        78059  2025-11-06     1       6     True
#
#       is_very_slow  is_critical   z_score
# 1909         False        False  3.771512
# 2082         False        False  3.619677
# 2099         False        False  3.710012
# 2107         False        False  4.307683
# 5314         False        False  3.293175
